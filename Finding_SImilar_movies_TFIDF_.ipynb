# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv("movies.csv")
netflixTitles = pd.read_csv("netflix_titles.csv")
netflixOrig = pd.read_csv("NetflixOriginals.csv")

# %%
#lowercase the names
netflixOrig = netflixOrig.rename(str.lower, axis='columns')
netflixTitles = netflixTitles.rename(str.lower, axis='columns')

#merge two netflix columns
merged = pd.merge(netflixOrig, netflixTitles, how = "inner", on = "title")

# %%
#DATA CLEANUP OF MERGED (trying to match movie dataset)

#Get all the movies between January 2000 to August 2023
merged = merged[(merged["release_year"] >= 2000) & (merged["release_year"] <= 2023)]

#Get all movies in English, we have 346 rows after this
merged = merged[merged["language"] == "English"]

#Clean up title, genre, description, cast, director
#lowercase
#no punctuation sub it with a space 
merged["title"] = merged["title"].str.lower().str.replace('[^\w\s]',' ', regex=True)
merged["genre"] = merged["genre"].str.lower().str.replace('[^\w\s]',' ', regex=True)
merged["description"] = merged["description"].str.lower().str.replace('[^\w\s]',' ', regex=True)
merged["cast"] = merged["cast"].str.lower().str.replace('[^\w\s]',' ', regex=True)
merged["director"] = merged["director"].str.lower().str.replace('[^\w\s]',' ', regex=True)

#dropped unnecessary columns
merged = merged.drop(columns = ["show_id", "date_added", "duration", "listed_in"])

# %%
#Get important features
for i in range(0, merged.shape[0]):
   merged["features"] = (merged["title"] + " " + merged["genre"] + " " + merged["description"])


#drop nan values from "features"
merged = merged.dropna(subset = ["features"])

merged["features"]
# Out:
# 3      the open house horror thriller following a tra...
# 7      the last days of american crime heist film thr...
# 8      paradox musical western fantasy neil young and...
# 13     mercy thriller two brothers clash with their h...
# 16     the last thing he wanted political thriller a ...
#                              ...
# 498    klaus animation christmas comedy adventure a s...
# 499    seaspiracy documentary passionate about ocean ...
# 501    dancing with the birds documentary from ruffli...
# 503    springsteen on broadway one man show bruce spr...
# 504    david attenborough  a life on our planet docum...
# Name: features, Length: 346, dtype: object

# %%
#DATA CLEANUP OF MOVIES COPIED FROM REVENUE MODEL FOR CONSISTENCY
#Get all the released movies 
movies = movies[movies['status'] == 'Released']

#Get all the movies between January 2000 to August 2023
movies = movies[(movies['release_date'] >= '2014-01-01') & (movies['release_date'] <= '2023-08-31')]

#Get all movies that have English as original language?? 
#Might be easier to build model and predict revenue if we eliminate disparties that could come from diff countries
movies = movies[movies['original_language'] == 'en']

#Off the bat these columns seem pretty useless so deleting them
movies = movies.drop(['poster_path', 'backdrop_path', 'recommendations'], axis=1)

#Drop null runtime
movies = movies[(movies['runtime'].isnull()) == False]

movies = movies[movies['revenue'] != 0]


#Clean up genres,title,  overview, credits 
#lowercase
#no punctuation sub it with a space 
movies["genres"] = movies["genres"].str.lower().str.replace('[^\w\s]',' ', regex=True)
movies["title"] = movies["title"].str.lower().str.replace('[^\w\s]',' ', regex=True)
movies["overview"] = movies["overview"].str.lower().str.replace('[^\w\s]',' ', regex=True)
movies["credits"] = movies["credits"].str.lower().str.replace('[^\w\s]',' ', regex=True)
movies["keywords"] = movies["keywords"].str.lower().str.replace('[^\w\s]',' ', regex=True)

movies
# Out:
#             id                              title  \
# 0       615656                  meg 2  the trench
# 1       758323                the pope s exorcist
# 2       667538   transformers  rise of the beasts
# 3       640146  ant man and the wasp  quantumania
# 4       677179                          creed iii
# ...        ...                                ...
# 718621  543887                      abuela s luck
# 719150  544967                   romeo and juliet
# 719372  576819                     active shooter
# 720449  554742               salty reef interview
# 722025  545416                            gestalt
#
#                                   genres original_language  \
# 0          action science fiction horror                en
# 1                horror mystery thriller                en
# 2       action adventure science fiction                en
# 3       action adventure science fiction                en
# 4                           drama action                en
# ...                                  ...               ...
# 718621                drama comedy crime                en
# 719150              comedy romance drama                en
# 719372                 documentary crime                en
# 720449                comedy documentary                en
# 722025                    drama thriller                en
#
#                                                  overview  popularity  \
# 0       an exploratory dive into the deepest depths of...    8763.998
# 1       father gabriele amorth chief exorcist of the v...    5953.227
# 2       when a new threat capable of destroying the en...    5409.104
# 3       super hero partners scott lang and hope van dy...    4425.387
# 4       after dominating the boxing world adonis creed...    3994.342
# ...                                                   ...         ...
# 718621  abuela s luck is a story about appreciation an...       0.600
# 719150  adaption of william shakespeare s classic trag...       0.600
# 719372  a documentary regarding the active shooter phe...       0.600
# 720449  a seasoned reporter is faced by a new challeng...       0.600
# 722025  a gestalt therapist investigates the tragic ev...       0.600
#
#                                      production_companies release_date  \
# 0       Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 1       Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2       Skydance-Paramount-di Bonaventura Pictures-Bay...   2023-06-06
# 3                  Marvel Studios-Kevin Feige Productions   2023-02-15
# 4       Metro-Goldwyn-Mayer-Proximity Media-Balboa Pro...   2023-03-01
# ...                                                   ...          ...
# 718621                                                NaN   2018-08-25
# 719150                                           Memeteam   2015-12-13
# 719372               U.S. Department of Homeland Security   2017-04-01
# 720449                                                NaN   2016-04-17
# 722025                                                NaN   2016-03-13
#
#              budget      revenue  runtime    status  \
# 0       129000000.0  352056482.0    116.0  Released
# 1        18000000.0   65675816.0    103.0  Released
# 2       200000000.0  407045464.0    127.0  Released
# 3       200000000.0  475766228.0    125.0  Released
# 4        75000000.0  269000000.0    116.0  Released
# ...             ...          ...      ...       ...
# 718621       8000.0      10000.0      9.0  Released
# 719150          0.0        100.0     16.0  Released
# 719372     150000.0     250000.0     90.0  Released
# 720449          0.0         75.0      1.0  Released
# 722025          0.0        250.0      5.0  Released
#
#                                                   tagline  vote_average  \
# 0                                       Back for seconds.         7.079
# 1       Inspired by the actual files of Father Gabriel...         7.433
# 2                                          Unite or fall.         7.340
# 3                 Witness the beginning of a new dynasty.         6.507
# 4                           You can't run from your past.         7.262
# ...                                                   ...           ...
# 718621  A young man's relationship with his grandmothe...         7.000
# 719150                                                NaN         0.000
# 719372                  Everything you need for survival.         0.000
# 720449     If our reefs could speak, what would they say?        10.000
# 722025                                                NaN         0.000
#
#         vote_count                                            credits  \
# 0           1365.0  jason statham wu jing shuya sophia cai sergio ...
# 1            545.0  russell crowe daniel zovatto alex essoe franco...
# 2           1007.0  anthony ramos dominique fishback luna lauren v...
# 3           2811.0  paul rudd evangeline lilly jonathan majors kat...
# 4           1129.0  michael b  jordan tessa thompson jonathan majo...
# ...            ...                                                ...
# 718621         1.0  manny ureña manuel cabrero wilton guzman shaki...
# 719150         0.0  james andersson filip holmberg alicia hirvenoj...
# 719372         0.0  connor patrick griffin kristina anderson dave ...
# 720449         1.0                                     cameron hazlip
# 722025         0.0                        ezra wood gabrielle mycroft
#
#                                                  keywords
# 0                     based on novel or book sequel kaiju
# 1       spain rome italy vatican pope pig possession c...
# 2       peru alien end of the world based on cartoon b...
# 3       hero ant sequel superhero based on comic famil...
# 4       philadelphia pennsylvania husband wife relatio...
# ...                                                   ...
# 718621  robbery latin hold up robbery underage drinkin...
# 719150                                                NaN
# 719372                                                NaN
# 720449                   coral reef interview satire reef
# 722025                                                NaN
#
# [3149 rows x 17 columns]

# %%
movies2 = movies.copy()
for i in range(0, movies2.shape[0]):
    movies2["features"] = (movies2["title"] + " " + movies2["genres"] + " " + movies2["overview"])

movies2["features"]

movies2 = movies2.dropna(subset = ["features"])

movies2
# Out:
#             id                              title  \
# 0       615656                  meg 2  the trench
# 1       758323                the pope s exorcist
# 2       667538   transformers  rise of the beasts
# 3       640146  ant man and the wasp  quantumania
# 4       677179                          creed iii
# ...        ...                                ...
# 718621  543887                      abuela s luck
# 719150  544967                   romeo and juliet
# 719372  576819                     active shooter
# 720449  554742               salty reef interview
# 722025  545416                            gestalt
#
#                                   genres original_language  \
# 0          action science fiction horror                en
# 1                horror mystery thriller                en
# 2       action adventure science fiction                en
# 3       action adventure science fiction                en
# 4                           drama action                en
# ...                                  ...               ...
# 718621                drama comedy crime                en
# 719150              comedy romance drama                en
# 719372                 documentary crime                en
# 720449                comedy documentary                en
# 722025                    drama thriller                en
#
#                                                  overview  popularity  \
# 0       an exploratory dive into the deepest depths of...    8763.998
# 1       father gabriele amorth chief exorcist of the v...    5953.227
# 2       when a new threat capable of destroying the en...    5409.104
# 3       super hero partners scott lang and hope van dy...    4425.387
# 4       after dominating the boxing world adonis creed...    3994.342
# ...                                                   ...         ...
# 718621  abuela s luck is a story about appreciation an...       0.600
# 719150  adaption of william shakespeare s classic trag...       0.600
# 719372  a documentary regarding the active shooter phe...       0.600
# 720449  a seasoned reporter is faced by a new challeng...       0.600
# 722025  a gestalt therapist investigates the tragic ev...       0.600
#
#                                      production_companies release_date  \
# 0       Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 1       Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2       Skydance-Paramount-di Bonaventura Pictures-Bay...   2023-06-06
# 3                  Marvel Studios-Kevin Feige Productions   2023-02-15
# 4       Metro-Goldwyn-Mayer-Proximity Media-Balboa Pro...   2023-03-01
# ...                                                   ...          ...
# 718621                                                NaN   2018-08-25
# 719150                                           Memeteam   2015-12-13
# 719372               U.S. Department of Homeland Security   2017-04-01
# 720449                                                NaN   2016-04-17
# 722025                                                NaN   2016-03-13
#
#              budget      revenue  runtime    status  \
# 0       129000000.0  352056482.0    116.0  Released
# 1        18000000.0   65675816.0    103.0  Released
# 2       200000000.0  407045464.0    127.0  Released
# 3       200000000.0  475766228.0    125.0  Released
# 4        75000000.0  269000000.0    116.0  Released
# ...             ...          ...      ...       ...
# 718621       8000.0      10000.0      9.0  Released
# 719150          0.0        100.0     16.0  Released
# 719372     150000.0     250000.0     90.0  Released
# 720449          0.0         75.0      1.0  Released
# 722025          0.0        250.0      5.0  Released
#
#                                                   tagline  vote_average  \
# 0                                       Back for seconds.         7.079
# 1       Inspired by the actual files of Father Gabriel...         7.433
# 2                                          Unite or fall.         7.340
# 3                 Witness the beginning of a new dynasty.         6.507
# 4                           You can't run from your past.         7.262
# ...                                                   ...           ...
# 718621  A young man's relationship with his grandmothe...         7.000
# 719150                                                NaN         0.000
# 719372                  Everything you need for survival.         0.000
# 720449     If our reefs could speak, what would they say?        10.000
# 722025                                                NaN         0.000
#
#         vote_count                                            credits  \
# 0           1365.0  jason statham wu jing shuya sophia cai sergio ...
# 1            545.0  russell crowe daniel zovatto alex essoe franco...
# 2           1007.0  anthony ramos dominique fishback luna lauren v...
# 3           2811.0  paul rudd evangeline lilly jonathan majors kat...
# 4           1129.0  michael b  jordan tessa thompson jonathan majo...
# ...            ...                                                ...
# 718621         1.0  manny ureña manuel cabrero wilton guzman shaki...
# 719150         0.0  james andersson filip holmberg alicia hirvenoj...
# 719372         0.0  connor patrick griffin kristina anderson dave ...
# 720449         1.0                                     cameron hazlip
# 722025         0.0                        ezra wood gabrielle mycroft
#
#                                                  keywords  \
# 0                     based on novel or book sequel kaiju
# 1       spain rome italy vatican pope pig possession c...
# 2       peru alien end of the world based on cartoon b...
# 3       hero ant sequel superhero based on comic famil...
# 4       philadelphia pennsylvania husband wife relatio...
# ...                                                   ...
# 718621  robbery latin hold up robbery underage drinkin...
# 719150                                                NaN
# 719372                                                NaN
# 720449                   coral reef interview satire reef
# 722025                                                NaN
#
#                                                  features
# 0       meg 2  the trench action science fiction horro...
# 1       the pope s exorcist horror mystery thriller fa...
# 2       transformers  rise of the beasts action advent...
# 3       ant man and the wasp  quantumania action adven...
# 4       creed iii drama action after dominating the bo...
# ...                                                   ...
# 718621  abuela s luck drama comedy crime abuela s luck...
# 719150  romeo and juliet comedy romance drama adaption...
# 719372  active shooter documentary crime a documentary...
# 720449  salty reef interview comedy documentary a seas...
# 722025  gestalt drama thriller a gestalt therapist inv...
#
# [3032 rows x 18 columns]

# %%
#PLAN
#make one large dataset, concatenate netflix and theatre movie data sets 
#make a binary column: isNetflix yes/no 
#give row id to every movie
#use TD IDF vectorizer to create big matrix
#use cosine similarity to compare rows/find most similar
#check if it isNetflix and show only non netflix similar movies

# %%
#We need to concatenate both datasets to put them in TF-IDF vectorizer
#After that we can create a vector matrix and find similar rows by using cosine_similarity
#When we find similar movies we will just make sure that thw most similar movie is not a Netflix movie
netflixDf = merged.copy()
theatreDf = movies2.copy()

#create a column isNetflix to differentiate between two datasets
netflixDf["isNetflix"] = 1
theatreDf["isNetflix"] = 0

#concatenating 
netflix_theatre_concat = pd.concat([netflixDf, theatreDf], axis=0)

netflix_theatre_concat
# Out:
#                                   title                    genre  \
# 3                        the open house          horror thriller
# 7       the last days of american crime      heist film thriller
# 8                               paradox  musical western fantasy
# 13                                mercy                 thriller
# 16             the last thing he wanted       political thriller
# ...                                 ...                      ...
# 718621                    abuela s luck                      NaN
# 719150                 romeo and juliet                      NaN
# 719372                   active shooter                      NaN
# 720449             salty reef interview                      NaN
# 722025                          gestalt                      NaN
#
#                  premiere  runtime  imdb score language show_id   type  \
# 3        January 19, 2018     94.0         3.2  English   s5074  Movie
# 7            June 5, 2020    149.0         3.7  English   s2425  Movie
# 8          March 23, 2018     73.0         3.9  English   s4973  Movie
# 13      November 22, 2016     90.0         4.2  English   s5710  Movie
# 16      February 21, 2020    115.0         4.3  English   s2898  Movie
# ...                   ...      ...         ...      ...     ...    ...
# 718621                NaN      9.0         NaN      NaN     NaN    NaN
# 719150                NaN     16.0         NaN      NaN     NaN    NaN
# 719372                NaN     90.0         NaN      NaN     NaN    NaN
# 720449                NaN      1.0         NaN      NaN     NaN    NaN
# 722025                NaN      5.0         NaN      NaN     NaN    NaN
#
#                          director  \
# 3       matt angel  suzanne coote
# 7                 olivier megaton
# 8                    daryl hannah
# 13                 chris sparling
# 16                       dee rees
# ...                           ...
# 718621                        NaN
# 719150                        NaN
# 719372                        NaN
# 720449                        NaN
# 722025                        NaN
#
#                                                      cast  ...  \
# 3       dylan minnette  piercey dalton  patricia bethu...  ...
# 7       edgar ramírez  michael pitt  anna brewster  pa...  ...
# 8       neil young  lukas nelson  micah nelson  corey ...  ...
# 13      james wolk  caitlin fitzgerald  tom lipinski  ...  ...
# 16      anne hathaway  ben affleck  willem dafoe  toby...  ...
# ...                                                   ...  ...
# 718621                                                NaN  ...
# 719150                                                NaN  ...
# 719372                                                NaN  ...
# 720449                                                NaN  ...
# 722025                                                NaN  ...
#
#                         production_companies release_date    budget   revenue  \
# 3                                        NaN          NaN       NaN       NaN
# 7                                        NaN          NaN       NaN       NaN
# 8                                        NaN          NaN       NaN       NaN
# 13                                       NaN          NaN       NaN       NaN
# 16                                       NaN          NaN       NaN       NaN
# ...                                      ...          ...       ...       ...
# 718621                                   NaN   2018-08-25    8000.0   10000.0
# 719150                              Memeteam   2015-12-13       0.0     100.0
# 719372  U.S. Department of Homeland Security   2017-04-01  150000.0  250000.0
# 720449                                   NaN   2016-04-17       0.0      75.0
# 722025                                   NaN   2016-03-13       0.0     250.0
#
#           status                                            tagline  \
# 3            NaN                                                NaN
# 7            NaN                                                NaN
# 8            NaN                                                NaN
# 13           NaN                                                NaN
# 16           NaN                                                NaN
# ...          ...                                                ...
# 718621  Released  A young man's relationship with his grandmothe...
# 719150  Released                                                NaN
# 719372  Released                  Everything you need for survival.
# 720449  Released     If our reefs could speak, what would they say?
# 722025  Released                                                NaN
#
#        vote_average vote_count  \
# 3               NaN        NaN
# 7               NaN        NaN
# 8               NaN        NaN
# 13              NaN        NaN
# 16              NaN        NaN
# ...             ...        ...
# 718621          7.0        1.0
# 719150          0.0        0.0
# 719372          0.0        0.0
# 720449         10.0        1.0
# 722025          0.0        0.0
#
#                                                   credits  \
# 3                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 13                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 718621  manny ureña manuel cabrero wilton guzman shaki...
# 719150  james andersson filip holmberg alicia hirvenoj...
# 719372  connor patrick griffin kristina anderson dave ...
# 720449                                     cameron hazlip
# 722025                        ezra wood gabrielle mycroft
#
#                                                  keywords
# 3                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 13                                                    NaN
# 16                                                    NaN
# ...                                                   ...
# 718621  robbery latin hold up robbery underage drinkin...
# 719150                                                NaN
# 719372                                                NaN
# 720449                   coral reef interview satire reef
# 722025                                                NaN
#
# [3378 rows x 34 columns]

# %%
#dropping duplicates from concatenated df 
netflix_theatre_concat1 = netflix_theatre_concat.drop_duplicates(subset=['title'])


netflix_theatre_concat = netflix_theatre_concat1.copy() #did this to avoid a weird warning

#giving each movie a movie_id to differentiate rows later
netflix_theatre_concat["movie_id"] = [i for i in range(0, netflix_theatre_concat.shape[0])]

# %%
#Converting our "feature" data to vectors using TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

vector = TfidfVectorizer()
vectors = vector.fit_transform(netflix_theatre_concat["features"]) 
vectors
# Out:
# <3175x15862 sparse matrix of type '<class 'numpy.float64'>'
# 	with 120147 stored elements in Compressed Sparse Row format>

# %%
print(vectors)
#A: Document index B: Specific word-vector index C: TFIDF score for word B in document A

#It indicates the tfidf score for all non-zero values in the word vector for each document.
# Out:
#   (0, 14149)	0.1446689138885501
#   (0, 580)	0.15433663443129692
#   (0, 3186)	0.30725364790630194
#   (0, 5619)	0.18629691267571286
#   (0, 14802)	0.28754772741409856
#   (0, 4611)	0.28754772741409856
#   (0, 15466)	0.14742555842079944
#   (0, 6746)	0.14317784482956492
#   (0, 15002)	0.22249217391192433
#   (0, 15001)	0.3228951169536776
#   (0, 11642)	0.30725364790630194
#   (0, 14310)	0.053394903172258534
#   (0, 9369)	0.2147509789015037
#   (0, 13131)	0.17046953189854605
#   (0, 14028)	0.21716280228408075
#   (0, 6603)	0.09797747078242591
#   (0, 817)	0.10940173030532734
#   (0, 9339)	0.1643115421446226
#   (0, 14429)	0.219735529379675
#   (0, 5598)	0.20637736629694958
#   (0, 14217)	0.09647754325668399
#   (0, 6812)	0.1117125110793326
#   (0, 6847)	0.1719825340250802
#   (0, 9969)	0.2286776496729017
#   (0, 14141)	0.045605098516711184
#   :	:
#   (3174, 460)	0.27130908583819674
#   (3174, 5972)	0.5426181716763935
#   (3174, 14164)	0.24884170877814935
#   (3174, 9876)	0.2356991357084589
#   (3174, 7432)	0.20823518426294857
#   (3174, 12059)	0.2581665127685063
#   (3174, 8430)	0.20823518426294857
#   (3174, 6588)	0.1326870543985788
#   (3174, 10331)	0.13501997271630428
#   (3174, 14430)	0.1907643815883641
#   (3174, 6455)	0.10700778708582938
#   (3174, 8452)	0.18944119486994035
#   (3174, 11136)	0.2356991357084589
#   (3174, 6673)	0.10944126938441273
#   (3174, 5003)	0.15897220053795974
#   (3174, 4398)	0.06033661924169548
#   (3174, 10125)	0.1333694706243291
#   (3174, 15594)	0.06838270886765234
#   (3174, 6691)	0.13344641180366934
#   (3174, 14139)	0.08101844956673145
#   (3174, 9903)	0.04521099404266143
#   (3174, 14310)	0.089728965273654
#   (3174, 817)	0.04596180288863492
#   (3174, 14217)	0.08106419914873195
#   (3174, 14141)	0.07663836916991748

# %%
from sklearn.metrics.pairwise import cosine_similarity
#cosine similarity (dot product of two vectors divided by magnitude of those vec)

cos_sim = cosine_similarity(vectors)

# %%
cos_sim.shape
# Out:
# (3175, 3175)

# %% [markdown]
# # Final Function:

# %%
def moviefinder_2(name):

    #Find the movie id of the title
    movID = netflix_theatre_concat[netflix_theatre_concat["title"] == name ]["movie_id"].values
    #checking if there are any matches of the movie
    if len(movID) > 0:
        #movie ID
        movID = movID[0]
        #cosine similarity scores for the movie ID
        score = list(enumerate(cos_sim[movID]))
        #sort based on the score, desc
        score_sort = sorted(score, key = lambda x:x[1], reverse = True)
        #the first value is the movie itself so we are removing it and starting from index 1
        score_sort = score_sort[1:]
    
        #creating a list for nonNetflix movies   
        nonNetflixSimilarMovies = []
        for movi, score in score_sort:
            mov_title = netflix_theatre_concat.iloc[movi]["title"]
            Netflix = netflix_theatre_concat.iloc[movi]["isNetflix"]
            #checking if the movie is not from Netflix
            if Netflix == 0: 
                #adding it to the list
                nonNetflixSimilarMovies.append(mov_title)
            #only giving 10 similar nonNetflix movies    
            if len(nonNetflixSimilarMovies)>=10:
                break
        #returns the first nonNetflix similar movie
        return nonNetflixSimilarMovies[:1] 
    else:
        #otherwise returns and empty list of the movie
        return []

# %% [markdown]
# # Manually evaluating netflix movies and similar theatre-released movies

# %%
moviefinder_2("tall girl") #match, both comedy/romance
# Out:
# ['she s funny that way']

# %%
moviefinder_2("army of the dead") #Match
# Out:
# ['not another zombie movie    about the living dead']

# %%
moviefinder_2("the princess switch") #Match
# Out:
# ['the secret princess']

# %%
moviefinder_2("the perfection") #Both movies about musical prodigies.

# "the perfection" is Horror, 'whiplash' is drama
# Out:
# ['whiplash']

# %%
moviefinder_2("wine country") #Both about a getaway with a group of friends
#"wine country"one is a fun birthday Napa getaway (comedy/drama)
#'the cabin house' is about a getaway that turns weekend of pure terror (horror)
# Out:
# ['the cabin house']

# %%
moviefinder_2("christmas inheritance") #MATCH Both Romance Movies, both about finding love in hometown/small town
# Out:
# ['the best of me']

# %%
newDf = netflixDf.copy()
newDf["Similar Movie"] = newDf["title"].apply(moviefinder_2)
newDf["Similar Movie"] = [",".join(map(str, i)) for i in newDf["Similar Movie"]]
newDf["movie_id"] = [i for i in range(0, newDf.shape[0])]

# %%
newDf
# Out:
#                                         title  \
# 3                              the open house
# 7             the last days of american crime
# 8                                     paradox
# 13                                      mercy
# 16                   the last thing he wanted
# ..                                        ...
# 498                                     klaus
# 499                                seaspiracy
# 501                    dancing with the birds
# 503                   springsteen on broadway
# 504  david attenborough  a life on our planet
#
#                                     genre           premiere  runtime  \
# 3                         horror thriller   January 19, 2018       94
# 7                     heist film thriller       June 5, 2020      149
# 8                 musical western fantasy     March 23, 2018       73
# 13                               thriller  November 22, 2016       90
# 16                     political thriller  February 21, 2020      115
# ..                                    ...                ...      ...
# 498  animation christmas comedy adventure  November 15, 2019       97
# 499                           documentary     March 24, 2021       89
# 501                           documentary   October 23, 2019       51
# 503                          one man show  December 16, 2018      153
# 504                           documentary    October 4, 2020       83
#
#      imdb score language show_id   type  \
# 3           3.2  English   s5074  Movie
# 7           3.7  English   s2425  Movie
# 8           3.9  English   s4973  Movie
# 13          4.2  English   s5710  Movie
# 16          4.3  English   s2898  Movie
# ..          ...      ...     ...    ...
# 498         8.2  English   s3274  Movie
# 499         8.2  English   s1172  Movie
# 501         8.3  English   s3387  Movie
# 503         8.5  English   s4294  Movie
# 504         9.0  English   s1887  Movie
#
#                                               director  \
# 3                            matt angel  suzanne coote
# 7                                      olivier megaton
# 8                                         daryl hannah
# 13                                      chris sparling
# 16                                            dee rees
# ..                                                 ...
# 498                                      sergio pablos
# 499                                        ali tabrizi
# 501                                         huw cordey
# 503                                         thom zimny
# 504  alastair fothergill  jonnie hughes  keith scholey
#
#                                                   cast  ...  \
# 3    dylan minnette  piercey dalton  patricia bethu...  ...
# 7    edgar ramírez  michael pitt  anna brewster  pa...  ...
# 8    neil young  lukas nelson  micah nelson  corey ...  ...
# 13   james wolk  caitlin fitzgerald  tom lipinski  ...  ...
# 16   anne hathaway  ben affleck  willem dafoe  toby...  ...
# ..                                                 ...  ...
# 498  jason schwartzman  j k  simmons  rashida jones...  ...
# 499                                                NaN  ...
# 501                                        stephen fry  ...
# 503                                  bruce springsteen  ...
# 504                                 david attenborough  ...
#
#             date_added release_year  rating duration  \
# 3     January 19, 2018         2018   TV-MA   95 min
# 7         June 5, 2020         2020   TV-MA  149 min
# 8       March 23, 2018         2018   TV-MA   74 min
# 13   November 22, 2016         2016   TV-MA   88 min
# 16   February 21, 2020         2020       R  116 min
# ..                 ...          ...     ...      ...
# 498  November 15, 2019         2019      PG   98 min
# 499     March 24, 2021         2021   TV-14   90 min
# 501   October 23, 2019         2019   TV-PG   52 min
# 503  December 16, 2018         2018   TV-MA  153 min
# 504    October 4, 2020         2020      PG   84 min
#
#                                           listed_in  \
# 3                          Horror Movies, Thrillers
# 7    Action & Adventure, Dramas, Independent Movies
# 8      Dramas, Independent Movies, Music & Musicals
# 13                                Dramas, Thrillers
# 16                                Dramas, Thrillers
# ..                                              ...
# 498              Children & Family Movies, Comedies
# 499                                   Documentaries
# 501                                   Documentaries
# 503                                Music & Musicals
# 504                                   Documentaries
#
#                                            description  \
# 3    following a tragedy  a mother and her teen son...
# 7    a bank robber joins a plot to commit one final...
# 8    neil young and his band of outlaws sow seeds o...
# 13   two brothers clash with their half siblings wh...
# 16   a hard hitting reporter becomes entangled in t...
# ..                                                 ...
# 498  a selfish postman and a reclusive toymaker for...
# 499  passionate about ocean life  a filmmaker sets ...
# 501  from ruffling their majestic feathers to naili...
# 503  bruce springsteen shares personal stories from...
# 504  a broadcaster recounts his life  and the evolu...
#
#                                               features isNetflix  \
# 3    the open house horror thriller following a tra...         1
# 7    the last days of american crime heist film thr...         1
# 8    paradox musical western fantasy neil young and...         1
# 13   mercy thriller two brothers clash with their h...         1
# 16   the last thing he wanted political thriller a ...         1
# ..                                                 ...       ...
# 498  klaus animation christmas comedy adventure a s...         1
# 499  seaspiracy documentary passionate about ocean ...         1
# 501  dancing with the birds documentary from ruffli...         1
# 503  springsteen on broadway one man show bruce spr...         1
# 504  david attenborough  a life on our planet docum...         1
#
#                                  Similar Movie movie_id
# 3                                   sinister 2        0
# 7                          the hurricane heist        1
# 8                               never grow old        2
# 13                                  the dinner        3
# 16                               winter s tale        4
# ..                                         ...      ...
# 498                           saving christmas      341
# 499                                 the batman      342
# 501                    the angry birds movie 2      343
# 503                       blinded by the light      344
# 504  the personal history of david copperfield      345
#
# [346 rows x 21 columns]

# %%
#Exporting csv file
newDf.to_csv("withSimilarMovies.csv")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=419f63df-2e68-44d4-9d98-aec60329482b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
